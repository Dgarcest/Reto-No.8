# %%
#Reto 8
#1. Imprimir un listado con los números del 1 al 100 cada uno con su respectivo cuadrado.

for i in range(101): #el ciclo va hasta el numero 100
    cuadrado = i*i #variable cuadrado de cada iteracion
    print(f"El numero es {i}, y su cuadrado {cuadrado}")
# Out:
# El numero es 0, y su cuadrado 0
# El numero es 1, y su cuadrado 1
# El numero es 2, y su cuadrado 4
# El numero es 3, y su cuadrado 9
# El numero es 4, y su cuadrado 16
# El numero es 5, y su cuadrado 25
# El numero es 6, y su cuadrado 36
# El numero es 7, y su cuadrado 49
# El numero es 8, y su cuadrado 64
# El numero es 9, y su cuadrado 81
# El numero es 10, y su cuadrado 100
# El numero es 11, y su cuadrado 121
# El numero es 12, y su cuadrado 144
# El numero es 13, y su cuadrado 169
# El numero es 14, y su cuadrado 196
# El numero es 15, y su cuadrado 225
# El numero es 16, y su cuadrado 256
# El numero es 17, y su cuadrado 289
# El numero es 18, y su cuadrado 324
# El numero es 19, y su cuadrado 361
# El numero es 20, y su cuadrado 400
# El numero es 21, y su cuadrado 441
# El numero es 22, y su cuadrado 484
# El numero es 23, y su cuadrado 529
# El numero es 24, y su cuadrado 576
# El numero es 25, y su cuadrado 625
# El numero es 26, y su cuadrado 676
# El numero es 27, y su cuadrado 729
# El numero es 28, y su cuadrado 784
# El numero es 29, y su cuadrado 841
# El numero es 30, y su cuadrado 900
# El numero es 31, y su cuadrado 961
# El numero es 32, y su cuadrado 1024
# El numero es 33, y su cuadrado 1089
# El numero es 34, y su cuadrado 1156
# El numero es 35, y su cuadrado 1225
# El numero es 36, y su cuadrado 1296
# El numero es 37, y su cuadrado 1369
# El numero es 38, y su cuadrado 1444
# El numero es 39, y su cuadrado 1521
# El numero es 40, y su cuadrado 1600
# El numero es 41, y su cuadrado 1681
# El numero es 42, y su cuadrado 1764
# El numero es 43, y su cuadrado 1849
# El numero es 44, y su cuadrado 1936
# El numero es 45, y su cuadrado 2025
# El numero es 46, y su cuadrado 2116
# El numero es 47, y su cuadrado 2209
# El numero es 48, y su cuadrado 2304
# El numero es 49, y su cuadrado 2401
# El numero es 50, y su cuadrado 2500
# El numero es 51, y su cuadrado 2601
# El numero es 52, y su cuadrado 2704
# El numero es 53, y su cuadrado 2809
# El numero es 54, y su cuadrado 2916
# El numero es 55, y su cuadrado 3025
# El numero es 56, y su cuadrado 3136
# El numero es 57, y su cuadrado 3249
# El numero es 58, y su cuadrado 3364
# El numero es 59, y su cuadrado 3481
# El numero es 60, y su cuadrado 3600
# El numero es 61, y su cuadrado 3721
# El numero es 62, y su cuadrado 3844
# El numero es 63, y su cuadrado 3969
# El numero es 64, y su cuadrado 4096
# El numero es 65, y su cuadrado 4225
# El numero es 66, y su cuadrado 4356
# El numero es 67, y su cuadrado 4489
# El numero es 68, y su cuadrado 4624
# El numero es 69, y su cuadrado 4761
# El numero es 70, y su cuadrado 4900
# El numero es 71, y su cuadrado 5041
# El numero es 72, y su cuadrado 5184
# El numero es 73, y su cuadrado 5329
# El numero es 74, y su cuadrado 5476
# El numero es 75, y su cuadrado 5625
# El numero es 76, y su cuadrado 5776
# El numero es 77, y su cuadrado 5929
# El numero es 78, y su cuadrado 6084
# El numero es 79, y su cuadrado 6241
# El numero es 80, y su cuadrado 6400
# El numero es 81, y su cuadrado 6561
# El numero es 82, y su cuadrado 6724
# El numero es 83, y su cuadrado 6889
# El numero es 84, y su cuadrado 7056
# El numero es 85, y su cuadrado 7225
# El numero es 86, y su cuadrado 7396
# El numero es 87, y su cuadrado 7569
# El numero es 88, y su cuadrado 7744
# El numero es 89, y su cuadrado 7921
# El numero es 90, y su cuadrado 8100
# El numero es 91, y su cuadrado 8281
# El numero es 92, y su cuadrado 8464
# El numero es 93, y su cuadrado 8649
# El numero es 94, y su cuadrado 8836
# El numero es 95, y su cuadrado 9025
# El numero es 96, y su cuadrado 9216
# El numero es 97, y su cuadrado 9409
# El numero es 98, y su cuadrado 9604
# El numero es 99, y su cuadrado 9801
# El numero es 100, y su cuadrado 10000

# %%
#2. Imprimir un listado con los números impares desde 1 hasta 999 y seguidamente otro listado con los números pares desde 2 hasta 1000.
    
for i in range(1, 1000, 2): #el ciclo va hasta 999 y va de 2 en 2
    print(f"numero impar: {i}")

print("Fin lista numeros impares") #separación 

for i in range(2, 1001, 2): #el ciclo va hasta 1000 y va de 2 en 2
    print(f"número par {i}")

print("Fin lista numeros pares") #separación
# Out:
# numero impar: 1
# numero impar: 3
# numero impar: 5
# numero impar: 7
# numero impar: 9
# numero impar: 11
# numero impar: 13
# numero impar: 15
# numero impar: 17
# numero impar: 19
# numero impar: 21
# numero impar: 23
# numero impar: 25
# numero impar: 27
# numero impar: 29
# numero impar: 31
# numero impar: 33
# numero impar: 35
# numero impar: 37
# numero impar: 39
# numero impar: 41
# numero impar: 43
# numero impar: 45
# numero impar: 47
# numero impar: 49
# numero impar: 51
# numero impar: 53
# numero impar: 55
# numero impar: 57
# numero impar: 59
# numero impar: 61
# numero impar: 63
# numero impar: 65
# numero impar: 67
# numero impar: 69
# numero impar: 71
# numero impar: 73
# numero impar: 75
# numero impar: 77
# numero impar: 79
# numero impar: 81
# numero impar: 83
# numero impar: 85
# numero impar: 87
# numero impar: 89
# numero impar: 91
# numero impar: 93
# numero impar: 95
# numero impar: 97
# numero impar: 99
# numero impar: 101
# numero impar: 103
# numero impar: 105
# numero impar: 107
# numero impar: 109
# numero impar: 111
# numero impar: 113
# numero impar: 115
# numero impar: 117
# numero impar: 119
# numero impar: 121
# numero impar: 123
# numero impar: 125
# numero impar: 127
# numero impar: 129
# numero impar: 131
# numero impar: 133
# numero impar: 135
# numero impar: 137
# numero impar: 139
# numero impar: 141
# numero impar: 143
# numero impar: 145
# numero impar: 147
# numero impar: 149
# numero impar: 151
# numero impar: 153
# numero impar: 155
# numero impar: 157
# numero impar: 159
# numero impar: 161
# numero impar: 163
# numero impar: 165
# numero impar: 167
# numero impar: 169
# numero impar: 171
# numero impar: 173
# numero impar: 175
# numero impar: 177
# numero impar: 179
# numero impar: 181
# numero impar: 183
# numero impar: 185
# numero impar: 187
# numero impar: 189
# numero impar: 191
# numero impar: 193
# numero impar: 195
# numero impar: 197
# numero impar: 199
# numero impar: 201
# numero impar: 203
# numero impar: 205
# numero impar: 207
# numero impar: 209
# numero impar: 211
# numero impar: 213
# numero impar: 215
# numero impar: 217
# numero impar: 219
# numero impar: 221
# numero impar: 223
# numero impar: 225
# numero impar: 227
# numero impar: 229
# numero impar: 231
# numero impar: 233
# numero impar: 235
# numero impar: 237
# numero impar: 239
# numero impar: 241
# numero impar: 243
# numero impar: 245
# numero impar: 247
# numero impar: 249
# numero impar: 251
# numero impar: 253
# numero impar: 255
# numero impar: 257
# numero impar: 259
# numero impar: 261
# numero impar: 263
# numero impar: 265
# numero impar: 267
# numero impar: 269
# numero impar: 271
# numero impar: 273
# numero impar: 275
# numero impar: 277
# numero impar: 279
# numero impar: 281
# numero impar: 283
# numero impar: 285
# numero impar: 287
# numero impar: 289
# numero impar: 291
# numero impar: 293
# numero impar: 295
# numero impar: 297
# numero impar: 299
# numero impar: 301
# numero impar: 303
# numero impar: 305
# numero impar: 307
# numero impar: 309
# numero impar: 311
# numero impar: 313
# numero impar: 315
# numero impar: 317
# numero impar: 319
# numero impar: 321
# numero impar: 323
# numero impar: 325
# numero impar: 327
# numero impar: 329
# numero impar: 331
# numero impar: 333
# numero impar: 335
# numero impar: 337
# numero impar: 339
# numero impar: 341
# numero impar: 343
# numero impar: 345
# numero impar: 347
# numero impar: 349
# numero impar: 351
# numero impar: 353
# numero impar: 355
# numero impar: 357
# numero impar: 359
# numero impar: 361
# numero impar: 363
# numero impar: 365
# numero impar: 367
# numero impar: 369
# numero impar: 371
# numero impar: 373
# numero impar: 375
# numero impar: 377
# numero impar: 379
# numero impar: 381
# numero impar: 383
# numero impar: 385
# numero impar: 387
# numero impar: 389
# numero impar: 391
# numero impar: 393
# numero impar: 395
# numero impar: 397
# numero impar: 399
# numero impar: 401
# numero impar: 403
# numero impar: 405
# numero impar: 407
# numero impar: 409
# numero impar: 411
# numero impar: 413
# numero impar: 415
# numero impar: 417
# numero impar: 419
# numero impar: 421
# numero impar: 423
# numero impar: 425
# numero impar: 427
# numero impar: 429
# numero impar: 431
# numero impar: 433
# numero impar: 435
# numero impar: 437
# numero impar: 439
# numero impar: 441
# numero impar: 443
# numero impar: 445
# numero impar: 447
# numero impar: 449
# numero impar: 451
# numero impar: 453
# numero impar: 455
# numero impar: 457
# numero impar: 459
# numero impar: 461
# numero impar: 463
# numero impar: 465
# numero impar: 467
# numero impar: 469
# numero impar: 471
# numero impar: 473
# numero impar: 475
# numero impar: 477
# numero impar: 479
# numero impar: 481
# numero impar: 483
# numero impar: 485
# numero impar: 487
# numero impar: 489
# numero impar: 491
# numero impar: 493
# numero impar: 495
# numero impar: 497
# numero impar: 499
# numero impar: 501
# numero impar: 503
# numero impar: 505
# numero impar: 507
# numero impar: 509
# numero impar: 511
# numero impar: 513
# numero impar: 515
# numero impar: 517
# numero impar: 519
# numero impar: 521
# numero impar: 523
# numero impar: 525
# numero impar: 527
# numero impar: 529
# numero impar: 531
# numero impar: 533
# numero impar: 535
# numero impar: 537
# numero impar: 539
# numero impar: 541
# numero impar: 543
# numero impar: 545
# numero impar: 547
# numero impar: 549
# numero impar: 551
# numero impar: 553
# numero impar: 555
# numero impar: 557
# numero impar: 559
# numero impar: 561
# numero impar: 563
# numero impar: 565
# numero impar: 567
# numero impar: 569
# numero impar: 571
# numero impar: 573
# numero impar: 575
# numero impar: 577
# numero impar: 579
# numero impar: 581
# numero impar: 583
# numero impar: 585
# numero impar: 587
# numero impar: 589
# numero impar: 591
# numero impar: 593
# numero impar: 595
# numero impar: 597
# numero impar: 599
# numero impar: 601
# numero impar: 603
# numero impar: 605
# numero impar: 607
# numero impar: 609
# numero impar: 611
# numero impar: 613
# numero impar: 615
# numero impar: 617
# numero impar: 619
# numero impar: 621
# numero impar: 623
# numero impar: 625
# numero impar: 627
# numero impar: 629
# numero impar: 631
# numero impar: 633
# numero impar: 635
# numero impar: 637
# numero impar: 639
# numero impar: 641
# numero impar: 643
# numero impar: 645
# numero impar: 647
# numero impar: 649
# numero impar: 651
# numero impar: 653
# numero impar: 655
# numero impar: 657
# numero impar: 659
# numero impar: 661
# numero impar: 663
# numero impar: 665
# numero impar: 667
# numero impar: 669
# numero impar: 671
# numero impar: 673
# numero impar: 675
# numero impar: 677
# numero impar: 679
# numero impar: 681
# numero impar: 683
# numero impar: 685
# numero impar: 687
# numero impar: 689
# numero impar: 691
# numero impar: 693
# numero impar: 695
# numero impar: 697
# numero impar: 699
# numero impar: 701
# numero impar: 703
# numero impar: 705
# numero impar: 707
# numero impar: 709
# numero impar: 711
# numero impar: 713
# numero impar: 715
# numero impar: 717
# numero impar: 719
# numero impar: 721
# numero impar: 723
# numero impar: 725
# numero impar: 727
# numero impar: 729
# numero impar: 731
# numero impar: 733
# numero impar: 735
# numero impar: 737
# numero impar: 739
# numero impar: 741
# numero impar: 743
# numero impar: 745
# numero impar: 747
# numero impar: 749
# numero impar: 751
# numero impar: 753
# numero impar: 755
# numero impar: 757
# numero impar: 759
# numero impar: 761
# numero impar: 763
# numero impar: 765
# numero impar: 767
# numero impar: 769
# numero impar: 771
# numero impar: 773
# numero impar: 775
# numero impar: 777
# numero impar: 779
# numero impar: 781
# numero impar: 783
# numero impar: 785
# numero impar: 787
# numero impar: 789
# numero impar: 791
# numero impar: 793
# numero impar: 795
# numero impar: 797
# numero impar: 799
# numero impar: 801
# numero impar: 803
# numero impar: 805
# numero impar: 807
# numero impar: 809
# numero impar: 811
# numero impar: 813
# numero impar: 815
# numero impar: 817
# numero impar: 819
# numero impar: 821
# numero impar: 823
# numero impar: 825
# numero impar: 827
# numero impar: 829
# numero impar: 831
# numero impar: 833
# numero impar: 835
# numero impar: 837
# numero impar: 839
# numero impar: 841
# numero impar: 843
# numero impar: 845
# numero impar: 847
# numero impar: 849
# numero impar: 851
# numero impar: 853
# numero impar: 855
# numero impar: 857
# numero impar: 859
# numero impar: 861
# numero impar: 863
# numero impar: 865
# numero impar: 867
# numero impar: 869
# numero impar: 871
# numero impar: 873
# numero impar: 875
# numero impar: 877
# numero impar: 879
# numero impar: 881
# numero impar: 883
# numero impar: 885
# numero impar: 887
# numero impar: 889
# numero impar: 891
# numero impar: 893
# numero impar: 895
# numero impar: 897
# numero impar: 899
# numero impar: 901
# numero impar: 903
# numero impar: 905
# numero impar: 907
# numero impar: 909
# numero impar: 911
# numero impar: 913
# numero impar: 915
# numero impar: 917
# numero impar: 919
# numero impar: 921
# numero impar: 923
# numero impar: 925
# numero impar: 927
# numero impar: 929
# numero impar: 931
# numero impar: 933
# numero impar: 935
# numero impar: 937
# numero impar: 939
# numero impar: 941
# numero impar: 943
# numero impar: 945
# numero impar: 947
# numero impar: 949
# numero impar: 951
# numero impar: 953
# numero impar: 955
# numero impar: 957
# numero impar: 959
# numero impar: 961
# numero impar: 963
# numero impar: 965
# numero impar: 967
# numero impar: 969
# numero impar: 971
# numero impar: 973
# numero impar: 975
# numero impar: 977
# numero impar: 979
# numero impar: 981
# numero impar: 983
# numero impar: 985
# numero impar: 987
# numero impar: 989
# numero impar: 991
# numero impar: 993
# numero impar: 995
# numero impar: 997
# numero impar: 999
# Fin lista numeros impares
# número par 2
# número par 4
# número par 6
# número par 8
# número par 10
# número par 12
# número par 14
# número par 16
# número par 18
# número par 20
# número par 22
# número par 24
# número par 26
# número par 28
# número par 30
# número par 32
# número par 34
# número par 36
# número par 38
# número par 40
# número par 42
# número par 44
# número par 46
# número par 48
# número par 50
# número par 52
# número par 54
# número par 56
# número par 58
# número par 60
# número par 62
# número par 64
# número par 66
# número par 68
# número par 70
# número par 72
# número par 74
# número par 76
# número par 78
# número par 80
# número par 82
# número par 84
# número par 86
# número par 88
# número par 90
# número par 92
# número par 94
# número par 96
# número par 98
# número par 100
# número par 102
# número par 104
# número par 106
# número par 108
# número par 110
# número par 112
# número par 114
# número par 116
# número par 118
# número par 120
# número par 122
# número par 124
# número par 126
# número par 128
# número par 130
# número par 132
# número par 134
# número par 136
# número par 138
# número par 140
# número par 142
# número par 144
# número par 146
# número par 148
# número par 150
# número par 152
# número par 154
# número par 156
# número par 158
# número par 160
# número par 162
# número par 164
# número par 166
# número par 168
# número par 170
# número par 172
# número par 174
# número par 176
# número par 178
# número par 180
# número par 182
# número par 184
# número par 186
# número par 188
# número par 190
# número par 192
# número par 194
# número par 196
# número par 198
# número par 200
# número par 202
# número par 204
# número par 206
# número par 208
# número par 210
# número par 212
# número par 214
# número par 216
# número par 218
# número par 220
# número par 222
# número par 224
# número par 226
# número par 228
# número par 230
# número par 232
# número par 234
# número par 236
# número par 238
# número par 240
# número par 242
# número par 244
# número par 246
# número par 248
# número par 250
# número par 252
# número par 254
# número par 256
# número par 258
# número par 260
# número par 262
# número par 264
# número par 266
# número par 268
# número par 270
# número par 272
# número par 274
# número par 276
# número par 278
# número par 280
# número par 282
# número par 284
# número par 286
# número par 288
# número par 290
# número par 292
# número par 294
# número par 296
# número par 298
# número par 300
# número par 302
# número par 304
# número par 306
# número par 308
# número par 310
# número par 312
# número par 314
# número par 316
# número par 318
# número par 320
# número par 322
# número par 324
# número par 326
# número par 328
# número par 330
# número par 332
# número par 334
# número par 336
# número par 338
# número par 340
# número par 342
# número par 344
# número par 346
# número par 348
# número par 350
# número par 352
# número par 354
# número par 356
# número par 358
# número par 360
# número par 362
# número par 364
# número par 366
# número par 368
# número par 370
# número par 372
# número par 374
# número par 376
# número par 378
# número par 380
# número par 382
# número par 384
# número par 386
# número par 388
# número par 390
# número par 392
# número par 394
# número par 396
# número par 398
# número par 400
# número par 402
# número par 404
# número par 406
# número par 408
# número par 410
# número par 412
# número par 414
# número par 416
# número par 418
# número par 420
# número par 422
# número par 424
# número par 426
# número par 428
# número par 430
# número par 432
# número par 434
# número par 436
# número par 438
# número par 440
# número par 442
# número par 444
# número par 446
# número par 448
# número par 450
# número par 452
# número par 454
# número par 456
# número par 458
# número par 460
# número par 462
# número par 464
# número par 466
# número par 468
# número par 470
# número par 472
# número par 474
# número par 476
# número par 478
# número par 480
# número par 482
# número par 484
# número par 486
# número par 488
# número par 490
# número par 492
# número par 494
# número par 496
# número par 498
# número par 500
# número par 502
# número par 504
# número par 506
# número par 508
# número par 510
# número par 512
# número par 514
# número par 516
# número par 518
# número par 520
# número par 522
# número par 524
# número par 526
# número par 528
# número par 530
# número par 532
# número par 534
# número par 536
# número par 538
# número par 540
# número par 542
# número par 544
# número par 546
# número par 548
# número par 550
# número par 552
# número par 554
# número par 556
# número par 558
# número par 560
# número par 562
# número par 564
# número par 566
# número par 568
# número par 570
# número par 572
# número par 574
# número par 576
# número par 578
# número par 580
# número par 582
# número par 584
# número par 586
# número par 588
# número par 590
# número par 592
# número par 594
# número par 596
# número par 598
# número par 600
# número par 602
# número par 604
# número par 606
# número par 608
# número par 610
# número par 612
# número par 614
# número par 616
# número par 618
# número par 620
# número par 622
# número par 624
# número par 626
# número par 628
# número par 630
# número par 632
# número par 634
# número par 636
# número par 638
# número par 640
# número par 642
# número par 644
# número par 646
# número par 648
# número par 650
# número par 652
# número par 654
# número par 656
# número par 658
# número par 660
# número par 662
# número par 664
# número par 666
# número par 668
# número par 670
# número par 672
# número par 674
# número par 676
# número par 678
# número par 680
# número par 682
# número par 684
# número par 686
# número par 688
# número par 690
# número par 692
# número par 694
# número par 696
# número par 698
# número par 700
# número par 702
# número par 704
# número par 706
# número par 708
# número par 710
# número par 712
# número par 714
# número par 716
# número par 718
# número par 720
# número par 722
# número par 724
# número par 726
# número par 728
# número par 730
# número par 732
# número par 734
# número par 736
# número par 738
# número par 740
# número par 742
# número par 744
# número par 746
# número par 748
# número par 750
# número par 752
# número par 754
# número par 756
# número par 758
# número par 760
# número par 762
# número par 764
# número par 766
# número par 768
# número par 770
# número par 772
# número par 774
# número par 776
# número par 778
# número par 780
# número par 782
# número par 784
# número par 786
# número par 788
# número par 790
# número par 792
# número par 794
# número par 796
# número par 798
# número par 800
# número par 802
# número par 804
# número par 806
# número par 808
# número par 810
# número par 812
# número par 814
# número par 816
# número par 818
# número par 820
# número par 822
# número par 824
# número par 826
# número par 828
# número par 830
# número par 832
# número par 834
# número par 836
# número par 838
# número par 840
# número par 842
# número par 844
# número par 846
# número par 848
# número par 850
# número par 852
# número par 854
# número par 856
# número par 858
# número par 860
# número par 862
# número par 864
# número par 866
# número par 868
# número par 870
# número par 872
# número par 874
# número par 876
# número par 878
# número par 880
# número par 882
# número par 884
# número par 886
# número par 888
# número par 890
# número par 892
# número par 894
# número par 896
# número par 898
# número par 900
# número par 902
# número par 904
# número par 906
# número par 908
# número par 910
# número par 912
# número par 914
# número par 916
# número par 918
# número par 920
# número par 922
# número par 924
# número par 926
# número par 928
# número par 930
# número par 932
# número par 934
# número par 936
# número par 938
# número par 940
# número par 942
# número par 944
# número par 946
# número par 948
# número par 950
# número par 952
# número par 954
# número par 956
# número par 958
# número par 960
# número par 962
# número par 964
# número par 966
# número par 968
# número par 970
# número par 972
# número par 974
# número par 976
# número par 978
# número par 980
# número par 982
# número par 984
# número par 986
# número par 988
# número par 990
# número par 992
# número par 994
# número par 996
# número par 998
# número par 1000
# Fin lista numeros pares

# %%
# 3. Imprimir los números pares en forma descendente hasta 2 que son menores o iguales a un número natural n ≥ 2 dado

n=int(input("Escriba su número: ")) #se pide el dato

if n%2 == 0: #cuando n es par
    for i in range(n, 1, -2): #el ciclo comienza en n y va disminuyendo 2 en cada iteracion
        print(i)

else: #cuando n es impar
    for i in range(n-1, 1, -2): #el ciclo comienza en n-1 y va disminuyendo 2 en cada iteracion
        print(i)
# Out:
# 18
# 16
# 14
# 12
# 10
# 8
# 6
# 4
# 2

# %%
#4. Imprimir los números de 1 hasta un número natural n dado, cada uno con su respectivo factorial

n = int(input("Introduzca el número: ")) #se le pide al usuario el dato

p = 1 #se declara una variable que va a ser la base para sacar el factorial en cada iteracion

for i in range (1, n+1): #lista de 1 hasta n
    p = p*i #la variable declarada p, se multiplica por i para sacar el factorial
    print(f"el numero es {i} y su factorial: {p}")
# Out:
# el numero es 1 y su factorial: 1
# el numero es 2 y su factorial: 2
# el numero es 3 y su factorial: 6
# el numero es 4 y su factorial: 24
# el numero es 5 y su factorial: 120
# el numero es 6 y su factorial: 720
# el numero es 7 y su factorial: 5040

# %%
#5. Calcular el valor de 2 elevado a la potencia n usando ciclos for

n = int(input("Ingrese la potencia: "))

p = 1 #valor inicial de 2 elevado a la potencia

for i in range (n): #va a tener n iteraciones
    p *= 2 #se multiplica 2 en cada iteracion

print(f"El valor de 2 elevado a la potencia {n} es: {p}") #se imprime el mensaje
# Out:
# El valor de 2 elevado a la potencia 7 es: 128

# %%
#6. Leer un número natural n, leer otro dato de tipo real x y calcular x^n usando ciclos for. Disclaimer: Trate de no utilizar el operador de potencia (**)

#se piden las 2 variables
n = int(input("Ingrese un numero natural: "))
x = float(input("Ingrese un numero real: "))
p = x 

for i in range(1, n): #lista desde 1 hasta n-1 (va a tener n-1 iteraciones)
    p = p*x #en cada iteracion se va a multiplica p(que es x) por si misma

print(f"El valor de {x}^{n} es de {p}")
# Out:
# El valor de 5.0^2 es de 25.0

# %%
# 7. Diseñe un programa que muestre las tablas de multiplicar del 1 al 9.

f = 1 #variable de las tablas

for i in range(1, 10): #ciclo de todas las tablas 
    for i in range(1, 11): #ciclo de cada una de las tablas
        n = f*i #f es la tabla en la que va, y i es el numero por el que se multiplica
        print(f"{f} x {i} = {n}")
    f += 1 #cuando sale del ciclo de una tabla se suma 1 a f para que vaya a la siguiente y asi sucesivamente
# Out:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %%
"""
8. Diseñar una función que permita calcular una aproximación de la función exponencial alrededor de 0 para cualquier valor x (real), utilizando los primeros n términos de la serie 
de Maclaurin. **Nota:** use *math* para traer la función exponencial y mostrar la diferencia entre el valor real y la aproximación.
"""

import math

def exponencial(x, n): #funcion para obtener el valor aproximado con la serie de Maclaurin
    valor = 0
    p = 1
    aproximacion = 0

    for i in range(n+1): #ciclo que es la serie

        p = p*i #factorial de i

        if p == 0: #if para que no salte error por la division por cero, y que en la aproximacion no falte la suma cuando i=0
            p = 1

        valor = (x**i)/(p)

        aproximacion += valor

    return aproximacion #al final la funcion retorna el resultado del ciclo (la aproximacion)


if __name__ == "__main__":
    #se ingresa x y teniendo en cuenta que n va a ser 10 por defecto
    x = float(input("Ingrese cualquier valor real para la aproximacion de la funcion exponencial con la serie de Maclaurin (con 10 terminos): "))
    #se llama a la funcion para el aproximado y se declara el valor real con el import math, math.exp(x)
    aprox = exponencial(x, 10)
    real = math.exp(x)
    print(f"La aproximacion con la serie de Maclaurin es {aprox} y el valor real es {real}")
    error = ((math.fabs(aprox - real))/real)*100 #formula de porcentaje de error
    print(f"El porcentaje de error es: {error}%")

    n = 10 #n va a ser inicialmente 10 (el n por defecto) y va a aumentar de 1 en 1 hasta el n con el porcentaje adecuado
    while error > 0.1: #si el porcentaje de error es mayor a 0.1 entonces el ciclo se va a repetir hasta que encuentre un n en el que el porcentaje sea menor a 0.1
        aprox = exponencial(x, n) #se llama a la misma funcion pero con el n alterado en cada iteracion
        if ((math.fabs(aprox - real))/real)*100 < 0.1: #cuando el % es menor a 0.1 se rompe el ciclo
            print(f"El numero de terminos o el valor de n con que el porcentaje de error es menor a 0.1 es {n}")
            break
        n += 1 #se suma 1 termino en cada iteracion

    n = 10 #n va a ser inicialmente 10 (el n por defecto) y va a disminuir de 1 en 1 hasta el n con el porcentaje adecuado
    while error < 0.1: #si el porcentaje de error es mucho menor a 0.1 entonces el ciclo se va a repetir hasta que encuentre un n en el que el porcentaje sea un poco mayor a 0.1
        aprox = exponencial(x, n) #se llama a la misma funcion pero con el n alterado en cada iteracion
        if ((math.fabs(aprox - real))/real)*100 > 0.1: #cuando el % es un poco mayor a 0.1 se rompe el ciclo
            print(f"El numero de terminos o el valor de n con que el porcentaje de error es menor a 0.1 es {n}")
            break
        n -= 1 #se resta 1 termino en cada iteracion
# Out:
# La aproximacion con la serie de Maclaurin es 2432.12126984127 y el valor real es 2980.9579870417283
# El porcentaje de error es: 18.411420744145342%
# El numero de terminos o el valor de n con que el porcentaje de error es menor a 0.1 es 18

# %%
"""
# 9. Diseñar una función que permita calcular una aproximación de la función seno alrededor de 0 para cualquier valor x (real), utilizando los primeros n términos 
de la serie de Maclaurin. **Nota:** use *math* para traer la función seno y mostrar la diferencia entre el valor real y la aproximación.
"""
import math

def serie(x, n): #funcion para calcular una aproximación de la función seno
    suma_total = 0 #variable de la suma de cada iteracion (de cada i en la serie)

    for i in range(0, n+1): #ciclo en el que cada iteracion es cada i en la serie
        #estas 2 variables son para calcular el factorial de 2*i+1
        k = 2*i + 1
        p = 1
        for j in range(1, k): #ciclo para calcular el factorial de k
            p = p*j
        total = p*k #este es el factorial de 2*i+1
        operacion = ((-1)**i)*(((x)**(2*i+1))/(total))
        suma_total += operacion
    return suma_total

if __name__ == "__main__":
    x = float(input("Ingrese cualquier valor real para la aproximacion de la funcion seno con la serie de Maclaurin (con 10 terminos): "))
    aproximacion = serie(x, 10)
    real = math.sin(x)
    print(f"La aproximacion de la funcion seno con la serie de Maclaurin es {aproximacion} y el valor real es {real}")
    error = math.fabs(((math.fabs(aproximacion - real))/real)*100) #formula de porcentaje de error (con un valor absoluto adicional porque a veces el "real" es negativo)
    print(f"El porcentaje de error es: {error}%")

    n = 10 #n va a ser inicialmente 10 (el n por defecto) y va a aumentar de 1 en 1 hasta el n con el porcentaje adecuado
    while error > 0.1: #si el porcentaje de error es mayor a 0.1 entonces el ciclo se va a repetir hasta que encuentre un n en el que el porcentaje sea menor a 0.1
        aproximacion = serie(x, n) #se llama a la misma funcion pero con el n alterado en cada iteracion
        if (math.fabs((math.fabs(aproximacion - real))/real)*100) < 0.1: #cuando el % es menor a 0.1 se rompe el ciclo
            print(f"El numero de terminos o el valor de n con que el porcentaje de error es menor a 0.1 es {n}")
            break
        n += 1 #se suma 1 termino en cada iteracion

    n = 10 #n va a ser inicialmente 10 (el n por defecto) y va a disminuir de 1 en 1 hasta el n con el porcentaje adecuado
    while error < 0.1: #si el porcentaje de error es mucho menor a 0.1 entonces el ciclo se va a repetir hasta que encuentre un n en el que el porcentaje sea un poco mayor a 0.1
        aproximacion = serie(x, n) #se llama a la misma funcion pero con el n alterado en cada iteracion
        if (math.fabs((math.fabs(aproximacion - real))/real)*100) > 0.1: #cuando el % es un poco mayor a 0.1 se rompe el ciclo
            print(f"El numero de terminos o el valor de n con que el porcentaje de error es menor a 0.1 es {n}")
            break
        n -= 1
# Out:
# La aproximacion de la funcion seno con la serie de Maclaurin es -0.7568024926569087 y el valor real es -0.7568024953079282
# El porcentaje de error es: 3.50292121320536e-07%
# El numero de terminos o el valor de n con que el porcentaje de error es menor a 0.1 es 6

# %%
"""
10. Diseñar una función que permita calcular una aproximación de la función arcotangente alrededor de 0 para cualquier valor x en el rango [-1, 1], utilizando los primeros n términos 
de la serie de Maclaurin. Nota: use math para traer la función arctan y mostrar la diferencia entre el valor real y la aproximación.
"""

import math

def arctan_aproximacion(x, n): #funcion para calcular una aproximación de la función arcotangente
    suma_serie = 0 #variable serie Maclaurin
    for i in range(n+1): #ciclo de 0 hasta n terminos
        operacion : float = ((-1)**i)*((x)**(2*i+1)/(2*i+1)) #operacion de la aproximacion
        suma_serie += operacion 
    return suma_serie #devuelve la suma total de los terminos

if __name__ == "__main__": 
    x = float(input("Ingrese cualquier valor en el rango [-1, 1] para la aproximacion de la funcion arcotangente con la serie de Maclaurin (con 10 terminos): "))
    while x>1 or x<-1: #si el valor de x no esta en el rango de [-1, 1] va a seguir pidiendo el dato hasta que este correcto
        print("Escriba un valor que este en el rango de [-1, 1]")
        x = float(input("Ingrese cualquier valor en el rango [-1, 1] para la aproximacion de la funcion arcotangente con la serie de Maclaurin (con 10 terminos): "))
    aproximacion = arctan_aproximacion(x, 10)
    valor_real = math.atan(x)
    print(f"La aproximacion de la funcion arcotangente con la serie de Maclaurin es {aproximacion} y el valor real es {valor_real}")
    error = math.fabs(((math.fabs(aproximacion - valor_real))/valor_real)*100) #formula de porcentaje de error
    print(f"El porcentaje de error es: {error}%")
        
    n = 10 #n va a ser inicialmente 10 (el n por defecto) y va a aumentar de 1 en 1 hasta el n con el porcentaje adecuado
    while error > 0.1: #si el porcentaje de error es mayor a 0.1 entonces el ciclo se va a repetir hasta que encuentre un n en el que el porcentaje sea menor a 0.1
        aproximacion = arctan_aproximacion(x, n) #se llama a la misma funcion pero con el n alterado en cada iteracion
        if (math.fabs((math.fabs(aproximacion - valor_real))/valor_real)*100) < 0.1: #cuando el % es menor a 0.1 se rompe el ciclo
            print(f"El numero de terminos o el valor de n con que el porcentaje de error es menor a 0.1 es {n}")
            break
        n += 1 #se suma 1 termino en cada iteracion

    n = 10 #n va a ser inicialmente 10 (el n por defecto) y va a disminuir de 1 en 1 hasta el n con el porcentaje adecuado
    while error < 0.1: #si el porcentaje de error es mucho menor a 0.1 entonces el ciclo se va a repetir hasta que encuentre un n en el que el porcentaje sea un poco mayor a 0.1
        aproximacion = arctan_aproximacion(x, n) #se llama a la misma funcion pero con el n alterado en cada iteracion
        if (math.fabs((math.fabs(aproximacion - valor_real))/valor_real)*100) > 0.1: #cuando el % es un poco mayor a 0.1 se rompe el ciclo
            print(f"El numero de terminos o el valor de n con que el porcentaje de error es menor a 0.1 es {n}")
            break
        n -= 1
# Out:
# La aproximacion de la funcion arcotangente con la serie de Maclaurin es 0.67490262988743 y el valor real es 0.6747409422235527
# El porcentaje de error es: 0.023962924695872783%
# El numero de terminos o el valor de n con que el porcentaje de error es menor a 0.1 es 7
